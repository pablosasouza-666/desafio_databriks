# %%
import os
print(os.getcwd())

# %%
# %sh
cd "/Workspace/Users/pablo.sa.souza@gmail.com/desafio_databriks_01"
git -c safe.directory="*" push https://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@github.com/pablosasouza-666/desafio_databriks.git master

# %%
# %sh
cd "/Workspace/Users/pablo.sa.souza@gmail.com/desafio_databriks_01"
git -c safe.directory="*" add 13_.ipynb "14_cdc_proposicoes.ipynb" git_push.ipynb Drafts/
git -c safe.directory="*" -c user.name="pablosasouza-666" -c user.email="pablo.sa.souza@gmail.com" commit -m "Adiciona notebooks restantes e CDC tramitacao"
git -c safe.directory="*" push https://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@github.com/pablosasouza-666/desafio_databriks.git master
